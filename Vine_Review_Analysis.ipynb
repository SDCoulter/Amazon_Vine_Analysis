# %%
# Import Pandas.
import pandas as pd

# %%
# Read in vine_table CSV.
df = pd.read_csv('vine_table.csv', sep=',')
df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R1KKOXHNI8MSXU          4.0            0.0          0.0    N
# 1        R26SP2OPDK4HT7          5.0            1.0          2.0    N
# 2         RWQEDYAX373I1          5.0            0.0          0.0    N
# 3        R231YI7R4GPF6J          5.0            0.0          0.0    N
# 4        R3KO3W45DD0L1K          5.0            0.0          0.0    N
# ...                 ...          ...            ...          ...  ...
# 5906328  R3638LBLGKMM2S          5.0            0.0          0.0    N
# 5906329   RP5AEIYZM5BUW          5.0           12.0         15.0    N
# 5906330  R3PB8K42BMNI40          3.0            0.0          0.0    N
# 5906331  R2PK1N9NG1JM4C          5.0            0.0          0.0    N
# 5906332  R2ORDL3TCNYNHC          4.0            0.0          0.0    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# 3                       Y
# 4                       Y
# ...                   ...
# 5906328                 Y
# 5906329                 Y
# 5906330                 Y
# 5906331                 Y
# 5906332                 Y
#
# [5906333 rows x 6 columns]

# %%
# Retrieve all rows where: total_votes count >= 20.
total_df = df.loc[df['total_votes'] >= 20]
total_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 211      R35PT06NWP7LDP          5.0           30.0         32.0    N
# 344      R2P76PJFUGXBHO          1.0            6.0         45.0    N
# 372       RQW4AFOG9MR4Z          5.0           51.0         52.0    N
# 406      R2SMUEBMGLAJQK          5.0           29.0         36.0    N
# 408      R1XVIZZALU5P6J          5.0          148.0        150.0    N
# ...                 ...          ...            ...          ...  ...
# 5905807  R1252ZFK9VRVQE          1.0           12.0         27.0    N
# 5905809  R1N9TEUZSMQLPO          1.0           20.0         27.0    N
# 5905816   R1K803RRJDEZS          5.0           46.0         66.0    N
# 5905820   R5XXKPQ9XI1TX          2.0           21.0         26.0    N
# 5905823  R2S1G9Q2KERBZ9          2.0           45.0         63.0    N
#
#         verified_purchase
# 211                     N
# 344                     N
# 372                     N
# 406                     Y
# 408                     Y
# ...                   ...
# 5905807                 Y
# 5905809                 N
# 5905816                 N
# 5905820                 N
# 5905823                 N
#
# [46909 rows x 6 columns]

# %%
# Retrieve all rows where: helpful_votes / total_votes >= 50%.
helpful_df = total_df.loc[df['helpful_votes'] / df['total_votes'] >= 0.5]
helpful_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 211      R35PT06NWP7LDP          5.0           30.0         32.0    N
# 372       RQW4AFOG9MR4Z          5.0           51.0         52.0    N
# 406      R2SMUEBMGLAJQK          5.0           29.0         36.0    N
# 408      R1XVIZZALU5P6J          5.0          148.0        150.0    N
# 419      R11UFMG8M2488I          4.0           23.0         26.0    N
# ...                 ...          ...            ...          ...  ...
# 5905511  R1A4PPQ8JLNQ0P          5.0           31.0         35.0    N
# 5905809  R1N9TEUZSMQLPO          1.0           20.0         27.0    N
# 5905816   R1K803RRJDEZS          5.0           46.0         66.0    N
# 5905820   R5XXKPQ9XI1TX          2.0           21.0         26.0    N
# 5905823  R2S1G9Q2KERBZ9          2.0           45.0         63.0    N
#
#         verified_purchase
# 211                     N
# 372                     N
# 406                     Y
# 408                     Y
# 419                     N
# ...                   ...
# 5905511                 N
# 5905809                 N
# 5905816                 N
# 5905820                 N
# 5905823                 N
#
# [45421 rows x 6 columns]

# %%
# Retrieve all rows where: vine == 'Y'  - (paid).
paid_df = helpful_df.loc[df['vine'] == 'Y']
paid_df.head()
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 50483   R6U9701C3BGO6          3.0          139.0        147.0    Y
# 50625  R1XK3ALB45D7N4          5.0           33.0         34.0    Y
# 50635  R1IZCSTLX81D6C          5.0           31.0         33.0    Y
# 50656  R2C8NC8EQLH4JF          3.0           45.0         48.0    Y
# 50890  R1JJ1YOJMOML1P          5.0           18.0         21.0    Y
#
#       verified_purchase
# 50483                 N
# 50625                 N
# 50635                 N
# 50656                 N
# 50890                 N

# %%
# Retrieve all rows where: vine == 'Y'  - (paid).
unpaid_df = helpful_df.loc[df['vine'] == 'N']
unpaid_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 211      R35PT06NWP7LDP          5.0           30.0         32.0    N
# 372       RQW4AFOG9MR4Z          5.0           51.0         52.0    N
# 406      R2SMUEBMGLAJQK          5.0           29.0         36.0    N
# 408      R1XVIZZALU5P6J          5.0          148.0        150.0    N
# 419      R11UFMG8M2488I          4.0           23.0         26.0    N
# ...                 ...          ...            ...          ...  ...
# 5905511  R1A4PPQ8JLNQ0P          5.0           31.0         35.0    N
# 5905809  R1N9TEUZSMQLPO          1.0           20.0         27.0    N
# 5905816   R1K803RRJDEZS          5.0           46.0         66.0    N
# 5905820   R5XXKPQ9XI1TX          2.0           21.0         26.0    N
# 5905823  R2S1G9Q2KERBZ9          2.0           45.0         63.0    N
#
#         verified_purchase
# 211                     N
# 372                     N
# 406                     Y
# 408                     Y
# 419                     N
# ...                   ...
# 5905511                 N
# 5905809                 N
# 5905816                 N
# 5905820                 N
# 5905823                 N
#
# [45388 rows x 6 columns]

# %% [markdown]
# ## Determine the total number of reviews, number of 5-star reviews, percentage of 5-star reviews for the two types of review.

# %%
# PAID - total number of reviews.
print(f"Total number of paid reviews reviews is {len(paid_df)}.")
# Out:
# Total number of paid reviews reviews is 33.

# %%
# PAID - total number of 5-star reviews.
print(f"Total number of paid 5-star reviews is {len(paid_df.loc[paid_df['star_rating'] == 5.0])}.")
# Out:
# Total number of paid 5-star reviews is 15.

# %%
# PAID - percentage of 5-star reviews.
print(f"The percentage of paid 5-star reviews is {(len(paid_df.loc[paid_df['star_rating'] == 5.0]) / len(paid_df)) * 100:.2f}%.")
# Out:
# The percentage of paid 5-star reviews is 45.45%.

# %%
# UNPAID - total number of reviews.
print(f"Total number of unpaid reviews reviews is {len(unpaid_df)}.")
# Out:
# Total number of unpaid reviews reviews is 45388.

# %%
# UNPAID - total number of 5-star reviews.
print(f"Total number of unpaid 5-star reviews is {len(unpaid_df.loc[unpaid_df['star_rating'] == 5.0])}.")
# Out:
# Total number of unpaid 5-star reviews is 23733.

# %%
# UNPAID - percentage of 5-star reviews.
print(f"The percentage of unpaid 5-star reviews is {(len(unpaid_df.loc[unpaid_df['star_rating'] == 5.0]) / len(unpaid_df)) * 100:.2f}%.")
# Out:
# The percentage of unpaid 5-star reviews is 52.29%.

# %% [markdown]
# ## Total 5-star reviews from whole set.

# %%
# UNPAID - total number of reviews.
print(f"Total number of usable reviews reviews is {len(helpful_df)}.")
# Out:
# Total number of usable reviews reviews is 45421.

# %%
# UNPAID - total number of 5-star reviews.
print(f"Total number of usable 5-star reviews is {len(helpful_df.loc[helpful_df['star_rating'] == 5.0])}.")
# Out:
# Total number of usable 5-star reviews is 23748.

# %%
# UNPAID - percentage of 5-star reviews.
print(f"The percentage of usable 5-star reviews is {(len(helpful_df.loc[helpful_df['star_rating'] == 5.0]) / len(helpful_df)) * 100:.2f}%.")
# Out:
# The percentage of usable 5-star reviews is 52.28%.
